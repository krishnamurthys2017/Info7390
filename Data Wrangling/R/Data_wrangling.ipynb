# %%
### Existing local data
mydata1 <- read.csv("student-mat.csv",sep=";",header=TRUE)
head(mydata1)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3       6        5  6  6
# 2 3        3     1    1    3       4        5  5  6
# 3 3        2     2    3    3      10        7  8 10
# 4 2        2     1    1    5       2       15 14 15
# 5 3        2     1    2    5       4        6 10 10
# 6 4        2     1    2    5      10       15 15 15

# %%
mydata2 <- read.table("student-mat.csv",sep=";",header=TRUE)
head(mydata2)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3       6        5  6  6
# 2 3        3     1    1    3       4        5  5  6
# 3 3        2     2    3    3      10        7  8 10
# 4 2        2     1    1    5       2       15 14 15
# 5 3        2     1    2    5       4        6 10 10
# 6 4        2     1    2    5      10       15 15 15

# %%
### Help with some external data
install.packages("quantmod")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(quantmod)

# %%
getSymbols("AAPL")
# Out:
# [1] "AAPL"

# %%
barChart(AAPL)
# Out:
# Plot with title “[2007-01-03/2017-09-20]”

# %%
barChart(AAPL['2017-09-01::2017-09-20'])
# Out:
# Plot with title “[2017-09-01/2017-09-20]”

# %%
### Accessing data from HTML webpage
### Needed package
install.packages("XML")
library(XML)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
u <- 'http://finance.yahoo.com/q/op?s=AAPL+Options'
tables = readHTMLTable(u)
names(tables)
# Out:
# Error: failed to load external entity "http://finance.yahoo.com/q/op?s=AAPL+Options"
#
# Traceback:
#
# 1. readHTMLTable(u)
# 2. readHTMLTable(u)
# 3. .local(doc, header, colClasses, skip.rows, trim, elFun, as.data.frame,
#  .     which, ...)
# 4. htmlParse(doc, encoding = encoding)
# 5. (function (msg, code, domain, line, col, level, filename, class = "XMLError")
#  . {
#  .     e = makeXMLError(msg, code, domain, line, col, level, filename,
#  .         class)
#  .     dom = names(e$domain)
#  .     class(e) = c(names(e$code), sprintf("%s_Error", gsub("_FROM_",
#  .         "_", dom)), class(e))
#  .     if (e$code == xmlParserErrors["XML_IO_LOAD_ERROR"])
#  .         stop(e)
#  . })("failed to load external entity \"http://finance.yahoo.com/q/op?s=AAPL+Options\"\n",
#  .     1549L, 8L, 0L, 0L, 1L, character(0))

# %%
tables[[2]] ### Accessing table #2 as an example
### Directly accessing table number 2 as an example
doc = htmlParse(u)
tableNodes = getNodeSet(doc, "//table")
tb = readHTMLTable(tableNodes[[2]])
tb
# Out:
# character(0)
