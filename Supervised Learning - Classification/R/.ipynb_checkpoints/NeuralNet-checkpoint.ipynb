# %%
install.packages('neuralnet')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
attach(infert)
library(neuralnet)
# Out:
# The following objects are masked from infert (pos = 3):
#
#     age, case, education, induced, parity, pooled.stratum, spontaneous,
#     stratum

# %%
neuralnet <- neuralnet(case ~ age + parity + induced + spontaneous, data=infert, 
                       hidden=3, err.fct="sse", linear.output=FALSE)
neuralnet$result.matrix
# Out:
#                         1
# error                     19.250694032550
# reached.threshold          0.009457116593
# steps                   3415.000000000000
# Intercept.to.1layhid1      0.033434652605
# age.to.1layhid1            1.731331922189
# parity.to.1layhid1         1.187356989576
# induced.to.1layhid1        0.840107620342
# spontaneous.to.1layhid1    0.588678870603
# Intercept.to.1layhid2    -16.785098776032
# age.to.1layhid2            0.215828007568
# parity.to.1layhid2         0.310470217440
# induced.to.1layhid2        2.944385696261
# spontaneous.to.1layhid2    3.559591606556
# Intercept.to.1layhid3     -4.276909285857
# age.to.1layhid3            0.140579141223
# parity.to.1layhid3        -3.355253222932
# induced.to.1layhid3        2.878451066635
# spontaneous.to.1layhid3    4.598554957607
# Intercept.to.case         -0.474947971951
# 1layhid.1.to.case         -1.672669798246
# 1layhid.2.to.case          3.454476734567
# 1layhid.3.to.case          3.632677266076

# %%
plot(neuralnet,rep = 'best')
# Out:
# plot without title

# %%
#Export dataset
data(infert)
write.csv(infert,"infert.csv")
