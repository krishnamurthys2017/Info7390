# %%
#Import xtrain from csv file
import pandas as pd
import numpy as np
xtrain = pd.read_csv("Khan_xtrain.csv", header = None)
del xtrain[0]
xtrain = xtrain[1:]

# %%
#Import ytrain from csv file
ytrain = pd.read_csv("Khan_ytrain.csv", header = None)
del ytrain[0]
ytrain = ytrain[1:]

# %%
xtrain[:10]
# Out:
#            1          2           3            4           5            6     \
# 1     0.7733437  -2.438405  -0.4825622    -2.721135   -1.217058    0.8278092
# 2   -0.07817778  -2.415754   0.4127717    -2.825146  -0.6262365   0.05448819
# 3   -0.08446916  -1.649739  -0.2413075    -2.875286  -0.8894054  -0.02747398
# 4      0.965614  -2.380547   0.6252965    -1.741256  -0.8453664    0.9496868
# 5     0.0756639  -1.728785   0.8526265    0.2726953    -1.84137    0.3279359
# 6     0.4588163  -2.875286   0.1358412    0.4053984   -2.082647    0.1378471
# 7    0.06709774  -1.624044   0.5196268    0.2382292   -1.397558     0.138805
# 8    0.09412766  -1.795165   0.7027509    0.2060381   -1.868209    0.2881819
# 9     0.1083161  -1.944911   0.6000994  -0.05108279   -1.981952    0.1192042
# 10    -0.970747  -2.347582  -0.3920061    -0.141218    -1.82325   -0.3035405
#
#         7           8            9           10       ...            2299  \
# 1   1.342604  0.05704174    0.1335689   0.5654274     ...       -0.238511
# 2   1.429498  -0.1202486    0.4567917   0.1590529     ...       -0.657394
# 3     1.1593  0.01567648    0.1919418   0.4965847     ...      -0.6963523
# 4   1.093801   0.8197358   -0.2846201   0.9947322     ...       0.2597455
# 5   1.251219   0.7714499    0.0309171   0.2783133     ...      -0.2004041
# 6    1.73353   0.3964244   0.04583342   0.3520643     ...       -1.131342
# 7   1.825291  -0.3054388  -0.05287349   -1.242367     ...       -1.836339
# 8   1.406072   0.7603384  -0.03905273   0.1361031     ...      -0.3191039
# 9   1.849116   0.2375197  -0.05034637  -0.2527011     ...      -0.3902317
# 10  1.498551  -0.2064094    0.1447927   -1.572142     ...       0.5369611
#
#            2300       2301         2302        2303       2304        2305  \
# 1   -0.02747398  -1.660205     0.588231   -0.463624  -3.952845   -5.496768
# 2    -0.2462842  -0.836325   -0.5712836  0.03478783   -2.47813   -3.661264
# 3    0.02498525  -1.059872   -0.4037666  -0.6786527  -2.939352    -2.73645
# 4     0.3571148  -1.893128    0.2551072   0.1633086  -1.021929   -2.077843
# 5     0.0617534  -2.273998  -0.03936472   0.3688011  -2.566551   -1.675044
# 6     -1.102018  -1.545994     -0.65778   0.3900807  -1.660205   -1.651302
# 7    0.03159556  -1.713133   -0.7316801   0.3806942  -3.051245  -0.2501294
# 8    0.09312598   -2.26915  -0.07785344   0.3455736  -2.570465   -1.730476
# 9    -0.4081186  -2.422495   -0.2638353  -0.6337468  -3.107782   -1.942815
# 10   -0.2261481  -2.302585    0.2358623  -0.9308969  -2.519498   -2.444149
#
#            2306        2307        2308
# 1     -1.414282  -0.6476004   -1.763172
# 2     -1.093923    -1.20932  -0.8243955
# 3     -1.965399   -0.805868   -1.139434
# 4     -1.127629   0.3315315   -2.179483
# 5      -1.08205  -0.9652184   -1.836966
# 6     -1.130722   -1.129175  0.04114194
# 7    -0.3649952   -1.969691   -1.421714
# 8     -1.116267  -0.9999441   -1.926206
# 9    -0.1185583   -2.691193   -2.221005
# 10  -0.05561842   -0.924071   -1.918003
#
# [10 rows x 2308 columns]

# %%
from sklearn import svm
X = xtrain
y = ytrain
clf = svm.SVC(kernel='linear')
clf.fit(X, y)
# Out:
# /Users/ngmodani/anaconda/lib/python3.5/site-packages/sklearn/svm/base.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y_ = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Import xtest from csv file
xtest = pd.read_csv("Khan_xtest.csv", header = None)
del xtest[0]
xtest = xtest[1:]

# %%
#Import ytest from csv file
ytest = pd.read_csv("Khan_ytest.csv", header = None)
del ytest[0]
ytest = ytest[1:]

# %%
#Make predictions on xtest dataset
pred = clf.predict(xtest)
pred
# Out:
# array(['3', '2', '4', '2', '1', '3', '4', '2', '3', '1', '3', '4', '1',
#        '2', '2', '2', '4', '2', '4', '2'], dtype=object)

# %%
#Performance on test dataset
pd.crosstab(pred,ytest[1],rownames=['pred'], colnames=['ytest'])
# Out:
# ytest  1  2  3  4
# pred
# 1      3  0  0  0
# 2      0  6  2  0
# 3      0  0  4  0
# 4      0  0  0  5
